# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
#
# Ans:
# *       --Expression
# 'hello' --value
# -87.8   --value
# -       --Expression
# /       --Expression
# +       --Expression
# 6       --Value

# %% [markdown]
# 2. What is the difference between string and variable?
# Ans:
# String is enclosed by single quotes or double quotes.
# Example: 'Diwakara' or "Diwakara"
# variable is used to  store the value.
# Example: diwakara = 100

# %% [markdown]
# 3. Describe three different data types.
# Ans:
# 1) List : List is a mutable data type in python.we can able to modify data in the list. List is enclosed by square bracket [].List is a unordered collection of data and indexing is applicable in list. Example: lst=[1,'deepu',3.12,"Bhasi"]
# 2)Tuple : Tuple is a immutable data type in python. We can not able to modify data in tuple.Tuple is enclosed by parentheses ().Tuple is unordered collection of data and indexing is applicable in tuple. Example: tup=(19,"naveen",8.7,'vinod')
# 3)String : String is a immutable data type in python.We can not modify data in the string.String is enclosed by single quotes '' or double quotes " " .String is a unordered collection of data and indexing is applicable in String. Example: 'Kiran' or "Charan"
# 4) Dictionary :Dictionary is a mutable data type in python.We can able to modify data in the list. Dictionary is enclosed by flower brackets and its contain key and value pair. Example: dict={1:'Murali',2:"soma"}
# 5) Set : set is unordered collection of data . it won't allows duplcate value and indexing is not applicable in set. set is enclosed by flower bracess.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
# Ans:
# Expression is made up of variables and mathametical operators.
# Expression does operation and gives us single value.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# Ans:
# Expression is made up of variables and mathametical oprators.
# statement is a command that python interpreter execute like print.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans:
# bacon =23

# %%
bacon=22
bacon+1
# Out:
# 23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Ans:
# The value is same in both operation.

# %%
'spam'+'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam'* 3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
# Ans:
# Variable is used to store the value.
# variable is having some rules in that number should not start with as a variable name.
# eggs is valid variable because it start with character.
# 100 is invalid variable because it start with number.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# Ans:
# Integer=int()
# Floating point number = float()
# string=str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# Ans: We can not add/concatenate  string with integer . We can use typecasting method to add integer and string.
